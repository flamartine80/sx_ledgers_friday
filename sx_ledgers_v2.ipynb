# %%
import pandas as pd
import xlwings as xw
import numpy as np
pd.set_option('display.max_columns', 1000, 'display.max_rows',1000, 'display.max_colwidth', None)

# z: 2018,a :2019, b:2020; c:2021; d:2022

# locations
d_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\20221231_SX Chile_General Ledger Dic22 (Acum).xlsx"
c_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\20211231_SX Chile_General Ledger Dic21 (Acum).xlsx"
b_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\20201231_SX Chile_General Ledger Dec20 (Acum).xlsx"
a_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\20191231_SX Chile_General Ledger December 2019 (Acum).xlsx"

d_fileName = "20221231_SX Chile_General Ledger Dic22 (Acum).xlsx"
c_fileName = "20211231_SX Chile_General Ledger Dic21 (Acum).xlsx"
b_fileName = "20201231_SX Chile_General Ledger Dec20 (Acum).xlsx"
a_fileName = "20191231_SX Chile_General Ledger December 2019 (Acum).xlsx"
z_fileName = '2018_mayor_SXChile.xlsx'


dump_fileName = "sxLedgers_dumpFile.xlsx"

d_rangeData = 'a1:o40000'
c_rangeData = 'a1:o40000'
b_rangeData = 'a1:o40000'
a_rangeData = 'a1:o40000'
z_rangeData = 'a1:o40000'

dump_rangeData = 'a1'
dump_rangeData_delete = 'a1:z30000'

d_sheet = 'CW202301265BEB'
c_sheet = 'CW20220126B561'
b_sheet = 'USD'
a_sheet = 'CW202001218740'
z_sheet = '2018'


dump_sheet = 'Sheet1'
dump_sheet_2 = 'Sheet2'


d_book = xw.Book(d_fileName)
c_book = xw.Book(c_fileName)
b_book = xw.Book(b_fileName)
a_book = xw.Book(a_fileName)
z_book = xw.Book(z_fileName)

x_book = xw.Book(a_fileName)
#---------D : 2022-------------------------------------------------------------------------------------------------------------

# Make DataFrame from spreadsheet
d_data = d_book.sheets(d_sheet).range(d_rangeData).value
df_d = pd.DataFrame(d_data)

#drop unnecesary columns
df_d_2 = df_d.drop([5,6,7,10], axis=1)
df_d_3 = df_d_2[df_d_2[0].str.contains('SALDO ANTERIOR')==False]
df_d_4 = df_d_3.dropna(thresh=2)

# ACCOUNT NAMES
df_d_accounts = df_d_2[df_d_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_d_4.columns = df_d_4.iloc[0]
df_d_4 = df_d_4[1:]

#DATE PARSING
df_d_4['FECHA']=pd.to_datetime(df_d_4['FECHA'], dayfirst=True)

#--------------C : 2021--------------------------------------------------------------------------------------------------------

#MAKE DATAFRAME FROM SPREADSHEET
c_data = c_book.sheets(c_sheet).range(c_rangeData).value
df_c = pd.DataFrame(c_data)

#DROP UNNECESARY COLUMNS
df_c_2 = df_c.drop([5,6,7,10], axis=1)
df_c_3 = df_c_2[df_c_2[0].str.contains('SALDO ANTERIOR')==False]
df_c_4 = df_c_3.dropna(thresh=2)

# ACCOUNT NAMES
df_c_accounts = df_c_2[df_c_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_c_4.columns = df_c_4.iloc[0]
df_c_4 = df_c_4[1:]

#PARSE DATE
df_c_4['FECHA']=pd.to_datetime(df_c_4['FECHA'], dayfirst=True)
#
#--------------B : 2020--------------------------------------------------------------------------------------------------------

#MAKE DATAFRAME FROM SPREADSHEET
b_data = b_book.sheets(b_sheet).range(b_rangeData).value
df_b = pd.DataFrame(b_data)

#DROP UNNECESARY COLUMNS
df_b_2 = df_b.drop([5,6,7,10], axis=1)
df_b_3 = df_b_2[df_b_2[0].str.contains('SALDO ANTERIOR')==False]
df_b_4 = df_b_3.dropna(thresh=2)

# ACCOUNT NAMES
df_b_accounts = df_b_2[df_b_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_b_4.columns = df_b_4.iloc[0]
df_b_4 = df_b_4[1:]

#PARSE DATE
df_b_4['FECHA']=pd.to_datetime(df_b_4['FECHA'], dayfirst=True)
#
#--------------A : 2019--------------------------------------------------------------------------------------------------------


#MAKE DATAFRAME FROM SPREADSHEET
a_data = a_book.sheets(a_sheet).range(a_rangeData).value
df_a = pd.DataFrame(a_data)

#DROP UNNECESARY COLUMNS
df_a_2 = df_a.drop([5,6,7,10], axis=1)
df_a_3 = df_a_2[df_a_2[0].str.contains('SALDO ANTERIOR')==False]
df_a_4 = df_a_3.dropna(thresh=2)

# ACCOUNT NAMES
df_a_accounts = df_a_2[df_a_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_a_4.columns = df_a_4.iloc[1]
df_a_4 = df_a_4[2:]

#PARSE DATE
df_a_4['FECHA']=pd.to_datetime(df_a_4['FECHA'], dayfirst=True)

# --------------Z : 2018--------------------------------------------------------------------------------------------------------

# MAKE DATAFRAME FROM SPREADSHEET
z_data = z_book.sheets(z_sheet).range(z_rangeData).value
df_z = pd.DataFrame(z_data)

#DROP UNNECESARY COLUMNS
df_z_2 = df_z.drop([5,6,7,10], axis=1)
df_z_3 = df_z_2[df_z_2[0].str.contains('SALDO ANTERIOR')==False]
df_z_4 = df_z_3.dropna(thresh=2)

# ACCOUNT NAMES76
df_z_accounts = df_z_2[df_z_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_z_4.columns = df_z_4.iloc[0]
df_z_4 = df_z_4[1:]

#PARSE DATE
df_z_4['FECHA']=pd.to_datetime(df_z_4['FECHA'], dayfirst=True)

# #-----------------------------------------------------------------------------------------------------------------------

joined_years = pd.concat([df_z_4,df_a_4,df_b_4,df_c_4,df_d_4])

acct_uniques = joined_years['CUENTA'].unique()

ACCOUNT = joined_years['CUENTA'].str.split(n=1, expand=True)
joined_years['NRO CUENTA'] = ACCOUNT[0]
joined_years['NOMBRE CUENTA'] = ACCOUNT[1]

#SECOND SPLIT

NOMBRE_CUENTA = joined_years['NOMBRE CUENTA'].str.split("/", n=1, expand=True)
joined_years['Account Name - English'] =NOMBRE_CUENTA[0]
joined_years['Account Name - Spanish'] = NOMBRE_CUENTA[1]

# acct_uniques= pd.Series(acct_uniques)

# #INFORMATION WRITE TO EXCEL
xw.Book(dump_fileName).sheets(dump_sheet).range(dump_rangeData_delete).value = ""
xw.Book(dump_fileName).sheets(dump_sheet).range(dump_rangeData).value = joined_years
# xw.Book(dump_fileName).sheets(dump_sheet_2).range(dump_rangeData_delete).value = ""
# xw.Book(dump_fileName).sheets(dump_sheet_2).range("a1:a1000").value = acct_uniques

# acct_uniques.str.split(n=1, expand=True)

tagua_tagua =joined_years[joined_years['DESCRIPCION'].str.contains('TAGUA TAGUA|taguatagua', case=False)==True]
tres_cruces =joined_years[joined_years['DESCRIPCION'].str.contains('tres cruces', case=False)==True]
andino =joined_years[joined_years['DESCRIPCION'].str.contains('ANDINO', case=False)==True]
storage =joined_years[joined_years['DESCRIPCION'].str.contains('storage', case=False)==True]
pelequen =joined_years[joined_years['DESCRIPCION'].str.contains('pelequen', case=False)==True]
quebradaTalca =joined_years[joined_years['DESCRIPCION'].str.contains('talca', case=False)==True]
greenfield =joined_years[joined_years['DESCRIPCION'].str.contains('greenfield', case=False)==True]
domeyko =joined_years[joined_years['DESCRIPCION'].str.contains('domeyko', case=False)==True]
corso =joined_years[joined_years['DESCRIPCION'].str.contains('santa lucia', case=False)==True]
angamos =joined_years[joined_years['DESCRIPCION'].str.contains('angamos', case=False)==True]
santaLucia =joined_years[joined_years['DESCRIPCION'].str.contains('don dario', case=False)==True]

# tres_cruces['NOMBRE CUENTA'].unique()

joined_years['NOMBRE CUENTA'].unique()
# Out:
# array(['Banco Santander CLP  / Santander CLP Bank                   ',
#        'Banco Santander USD / Santander USD Bank                    ',
#        'Cuentas por Cobrar / Trade Receivables                      ',
#        'Cuentas por Cobrar por Facturar / Unbilled Revenue          ',
#        'Cta Cte Emp Rel C-P / Related party current receivables     ',
#        'Cta Cte Emp Rel CLP / Due from other related party          ',
#        'Prepagos / Prepayments                                      ',
#        'Anticipo a empleados / Advances to employees                ',
#        'Anticipo a Proveedores / Advances to suppliers              ',
#        'Otros impuesto por cobrar / Other tax receivable            ',
#        'Pagos Provisionales Mensuales / Income Tax Prepayment       ',
#        'Inv. Atacama Solar SPA / Inv. Atacama Solar SPA             ',
#        'Inv. Cox Energy Chile SpA / Inv. Cox Energy Chile SpA       ',
#        'Inv. Tercera Región Solar SpA / Inv. Tercera Región Solar Sp',
#        'Equipos de Computación / Computer Hardware                  ',
#        'Instalaciones /Installations                                ',
#        'Muebles / Furniture                                         ',
#        'Deprec Acum Eq Computación / Computer Hardware Acum Dep     ',
#        'Deprec Acum Intalac /  Install Acum Dep                     ',
#        'Deprec Acum Muebles / Furniture Acum Dep                    ',
#        'Deprec Acum Eq Electronicos / Acc Dep Elect Equipment       ',
#        'Impuesto Diferido / Deferred Taxes                          ',
#        'Proyecto Valle Altillo / Project Valle Altillo              ',
#        'Proyecto Collahuasi / Project Collahuasi                    ',
#        'Proyecto Mesetas / Project Mesetas                          ',
#        'Proyecto Imelsa / Imelsa Project                            ',
#        'Proyecto Tres Cruces / Project Tres Cruces                  ',
#        'Proyecto Storage / Storage Proyect                          ',
#        'Proyecto Grenergy / Grenergy Proyect                        ',
#        'Garantía de arriendo / Rent Deposit                         ',
#        'Proveedores Nacionales / Trade Payables                     ',
#        'Proveedores extranjeros / Foreign Suppliers                 ',
#        'Provisión Impuesto a la Renta / Provision for Income Tax    ',
#        'PPM Pagadero / PPM Payable                                  ',
#        'Remuneraciones por Pagar / Staff costs payable              ',
#        'Honorarios por Pagar / Fees Payable                         ',
#        'Bono por pagar / Bonus payable                              ',
#        'Retenciones leyes sociales / Social security contrib payable',
#        'Impuesto Único / Employee Income Tax Payable                ',
#        'Retención Honorarios / Subcontracted Fees Withholding Tax   ',
#        'Cuentas por Pagar Vacaciones / Holiday pay accrual          ',
#        'Retenciones AFP / Pension Fund - Employees                  ',
#        'Retenciones ISAPRE / Private Health Insurance Withholding   ',
#        'Retenciones MUTUAL / Workers Comp. Withholding              ',
#        'Finiquitos por pagar / Staff leaving costs                  ',
#        'Otros Acreedores / Other Payables                           ',
#        'Inversiones por pagar / Investment payable                  ',
#        'Inter. devengos x pagar interco/ Accr interco inter. payable',
#        'Provisión SUKSL Intercompañías / SUKSL Services Fee         ',
#        'Pagar corrientes intercompañía / InterCo current payables   ',
#        'Préstamos USD Sx Latam Holding/ Sonnedix Latam Hol. SL Loan ',
#        'Préstamo Intercompañía CLP / Intercompany Loan CLP          ',
#        'Inv. Cox Energy por pagar / Inv. Cox Energy payable         ',
#        'Acciones suscritas / Shares subscribe                       ',
#        'Ing. Interco - Comisión Gestión / Interco Income - mgmt fee ',
#        'Otros Honorarios profesionales / Other Professional fees    ',
#        'Sueldos Base / Wages and salaries                           ',
#        'Gratificaciones / Legal Gratuity                            ',
#        'Bonos e Incentivos / Staff Bonuses                          ',
#        'Vacaciones & Feriado Proporcional / Holiday pay             ',
#        'Indemnización / Leaving indemnity                           ',
#        'Leyes Sociales / Social security contributions              ',
#        'Emplead. capacitación prof. / Emp vocational training costs ',
#        'Otras prestaciones del personal / Other staff benefits      ',
#        'Ases. Administrativa y Contable / Accounting Fees           ',
#        'Servicios de UK / UK Services fee                           ',
#        'Ases. Impuestos / Tax fees                                  ',
#        'Ases. Auditoria / Audit fees                                ',
#        'Gastos Legales - transac relac / Legal fees - trans. related',
#        'Gastos legales - general / Legal fees - general             ',
#        'Gastos notariales / Notary fees                             ',
#        'Honorarios - asesoramiento técnico / Technical advisory fees',
#        'Costos de administración / Administration costs             ',
#        'Licitación PPA privado / Private PPA tender                 ',
#        'Costo de reclutamiento / Recruiting cost                    ',
#        'Reajuste Impto x Rec / Monetary Correction Recoverable Taxes',
#        'Otros impuestos / Other taxes                               ',
#        'Arrendamiento operativo - Of.  / Op. lease costs - Offices  ',
#        'Consumos Básicos / Utilities                                ',
#        'Combustibles / Fuel                                         ',
#        'Telefonía Celular / Mobile Telephone                        ',
#        'Gastos informáticos - hardware / IT expenses - hardware     ',
#        'Courier y Transporte / Printing and postage                 ',
#        'Artículos de Oficina / Stationery                           ',
#        'Arriendos y Gastos Comunes / Rent & Associated Charges      ',
#        'Depn de Instalaciones / Depn of Intall                      ',
#        'Depn de los equipos informáticos / Depn of IT equipment     ',
#        'Depn de Muebles / Depn of Furniture                         ',
#        'Depn de Eq. Electronicos / Depn Electronic Equipment        ',
#        'Viajes / Travel costs                                       ',
#        'Hoteles / Hotels                                            ',
#        'Alimentación / Meals (subsistence)                          ',
#        'Compras de suministros admin. / Purchases of admin. supplies',
#        'Mejoras de Oficina / Office improvements                    ',
#        'Reparación y mant. - oficina / Office Repairs & Maint.      ',
#        'Otros gastos generales / Other overheads                    ',
#        'Asociaciones y Suscripciones / Associations & Subscriptions ',
#        'Publicidad y relaciones públicas / Advertising & P.R.       ',
#        'Seguros / Insurance Costs                                   ',
#        'Gastos Rechazados / Rejected Expenses                       ',
#        'Patentes Permisos / Licenses & Permits                      ',
#        'Gastos de seguridad / Security costs                        ',
#        'Intereses préstamos Interco / Interest charge Interco Loans ',
#        'Comisiones y gastos bancarios / Bank commissions and charges',
#        'No realizada gan/pérd - T/C / Unrealised FX profit or loss  ',
#        'Ganancia/pérdida camb.Realizado UF/Realised FX profit/loss  ',
#        'Impuesto a la Renta / Income Tax                            ',
#        'Otras cuentas por cobrar / Other receivables                ',
#        'Inv. SPV P4 SA / Inv. SPV P4 SA                             ',
#        'Equipos Electrónicos / Electronic equipment                 ',
#        'Impuesto Diferido ROU / Deferred Taxes ROU                  ',
#        'ActivoTerrenos arrendados (ROU) / Leased land asset (ROU)   ',
#        'Deprec Acum Terrenos arr (ROU) / Acc Dep Leased land (ROU)  ',
#        'Pago Formulario 50 / Foreign Withholding Tax Payable        ',
#        'Provisión Impuesto Gasto Rechazado / Prov Rejected Expenses ',
#        'Pasivo arrendamiento (ROU) / Lease liability (ROU)          ',
#        'Inv. SPV P4 por pagar / Inv. SPV P4 payable                 ',
#        'Capital Social / Share Capital                              ',
#        'Futuros Aumentos de Capital / Future Capital Contribution   ',
#        'Ventas de Explotación / Operating Revenue                   ',
#        'Otros Ingresos Fuera de la Explot / Other Non Op. Income    ',
#        'Relocación / Relocation                                     ',
#        'SIS/ Disability insurance                                   ',
#        'Seguro cesantía empresa / Unemployment insurance            ',
#        'Seguro accidente de trabajo / Work accident                 ',
#        'Proyecto Meseta fase II / Meseta fase II Proyect            ',
#        'Proyecto Tres Cruces / Tres Cruces Proyect                  ',
#        'Proyecto Atacama Solar fase III / AS fase III Proyect       ',
#        'Servicios de Terceros / Third party consultancy             ',
#        'Ases. IT & Insumos Computacionales / IT Services & Supplies ',
#        'Depreciación de arriendos de terreno (ROU) / Depreciation of',
#        'Intereses de Pasivos por arrendamiento (ROU) / Lease liabili',
#        'Impuesto Gastos Rechazados / Rejected Expenses              ',
#        'Depósito en tránsito / Deposit in transit - Cash (one week) ',
#        'Cta Cte Emp Rel C-P NAS / Related party current receivables ',
#        'Cta Cte Emp Rel C-P Cox / Related party current receivables ',
#        'Cta Cte Emp Rel C-P SPV / Related party current receivables ',
#        'Cta Cte Emp Rel C-P Malinke / Related party current receivab',
#        'Cta Cte Emp Rel C-P La Molina / Related party current receiv',
#        'Cta Cte Emp Rel C-P Donihue / Related party current receivab',
#        'Cta Cte Emp Rel C-P Marquesa / Related party current receiva',
#        'Cta Cte Emp Rel C-P Potroso / Related party current receivab',
#        'Cta Cte Emp Rel C-P Crucero / Related party current receivab',
#        'Cta Cte Emp Rel C-P La Serena / Related party current receiv',
#        'Cta Cte Emp Rel C-P AS / Related party current receivables  ',
#        'Cta Cte Emp Rel C-P TRS / Related party current receivables ',
#        'Cta Cte Emp Rel C-P Andino Occidente / Related party current',
#        'Cta Cte Emp Rel C-P Altos de la Manga / Related party curren',
#        'Cta Cte Emp Rel C-P Parronal / Related party current receiva',
#        'Cta Cte Emp Rel C-P El Queule / Related party current receiv',
#        'Cta Cte Emp Rel C-P Villa Prat / Related party current recei',
#        'Cta Cte Emp Rel C-P Pelequen / Related party current receiva',
#        'Intereses por cobrar / Interest receivable                  ',
#        'Inv. Sx Cox Energy Chile SpA / Inv. Sx Cox Energy Chile SpA ',
#        'Inv. Nueva Atacama Solar SA / Inv. Nueva Atacama Solar SA   ',
#        'Inv. Andino Occidente / Inv. Andino Occidente               ',
#        'Inv. Pelequen Solar SpA / Pelequen Solar SpA                ',
#        'Inv. Altos de la Manga Energy SpA / Inv. Altos de la Manga E',
#        'Inv. Parronal Energy SpA / Inv. Parronal Energy SpA         ',
#        'Inv. El Queule SpA / Inv. El Queule SpA                     ',
#        'Inv. Villa Prat Energy SpA / Inv. Villa Prat Energy SpA     ',
#        'Activo Oficinas (ROU) / Leased Offices                      ',
#        'Deprec Acum Offices arr (ROU) / Acc Dep Leased              ',
#        'Proyecto Bifacial / Bifacial Project                        ',
#        'Boleta en Garantía / Guaranteed deposits paid               ',
#        'Cta Cte Emp Rel Latam / Related party current payables      ',
#        'Acciones suscritas / Shares subscribed                      ',
#        'Ventas MarkUp Donihue / Income Mark Up Donihue              ',
#        'Ventas MarkUp La Molina / Income Mark Up La Molina          ',
#        'Ventas MarkUp Potroso / Income Mark Up Potroso              ',
#        'Ventas MarkUp Marquesa / Income Mark Up Marquesa            ',
#        'Gestión Atacama / Income mgmt fee Atacama                   ',
#        'Gestión SPV P4 / Income mgmt fee SPV P4                     ',
#        'Gestión Sonnedix Cox / Income mgmt fee Sonnedix Cox         ',
#        'Gestión Donihue / Income mgmt fee Donihue                   ',
#        'Gestión La Molina / Income mgmt fee La Molina               ',
#        'Gestión Potroso / Income mgmt fee Potroso                   ',
#        'Gestión Marquesa / Income mgmt fee Marquesa                 ',
#        'Gestión Altos de La Manga / Income mgmt fee Altos de La Mang',
#        'Gestión Parronal / Income mgmt fee Parronal                 ',
#        'Gestión El Queule / Income mgmt fee El Queule               ',
#        'Gestión Villa Prat / Income mgmt fee Villa Prat             ',
#        'Interés x cbr Cox Energy Solar / Interest Cox Energy Solar  ',
#        'Interés x cbr SPV P4 / Interest SPV P4                      ',
#        'Mantención Inmueble / Office Maintainance                   ',
#        'Otros bonos e Incentivos / Other Staff Bonuses              ',
#        'Proyecto Batería / Batery Proyect                           ',
#        'Proyecto TaguaTagua / TaguaTagua Proyect                    ',
#        'Donaciones / Donations                                      ',
#        'Honorario Consultores / Consultancy Fees M&A                ',
#        'Internet / Internet                                         ',
#        'Capacitación / Training                                     ',
#        'Banco Santander CLP 7546  / Santander CLP Bank 7546         ',
#        'Banco Santander USD 2781 / Santander USD Bank 2781          ',
#        'Banco Santander USD 9871/ Santander USD Bank 9871           ',
#        'Banco Santander CLP 5151 / Santander CLP Bank 5151          ',
#        'Ctas. Corr. Taranto / Current Receiv -Taranto               ',
#        'Cta Cte Emp Rel C-P SxET / Related party current receivable ',
#        'Ctas. Corr. SX PPA / Current Receiv -SX PPA                 ',
#        'Ctas. Corr. Quebrada De Talca / Current Receiv Quebrada De T',
#        'Préstamo a Empleados / Employee Loans                       ',
#        'Inv. Sx Energy Trading Chile SpA / Inv. Sx Energy Trading Ch',
#        'Inv. SX PPA / Investment Int. - SX PPA                      ',
#        'Impuestos Diferidos / Deferred Taxes                        ',
#        'Cta Cte Emp Rel C-P Taranto / Related party current receivab',
#        'Otras Retenciones / Other Withholdings                      ',
#        'Cta Cte Emp Rel TRS / Related party current payables        ',
#        'Ctas. Corr. SPV P4 / Current Liab - SPV P4                  ',
#        'Ctas. Corr.Atacama Solar / Current Liab - Atacama Solar     ',
#        'Cta Cte Emp Rel La Serena / Related party current payable   ',
#        'Inv. Andino O. por pagar / Inv. Andino O.                   ',
#        'Inv. Pelequen. por pagar / Inv. Pelequen                    ',
#        'Inv. SX PPA Por Pagar / Inv. SX PPA                         ',
#        'Impuestos Diferidos Rou / Deferred Taxes Rou                ',
#        'Gestión TRS / Income mgmt fee TRS                           ',
#        'Gestión Malinke / Income mgmt fee Malinke                   ',
#        'Gestión Taranto / Income mgmt fee Taranto                   ',
#        'Recupero Interco / Recovery interco                         ',
#        'Gestión Crucero / Income mgmt fee Crucero                   ',
#        'Interés x cbr El NAS / Interest NAS                         ',
#        'Interés x cbr Altos de la Manga / Interest Altos de la Manga',
#        'Interés x cbr El Queule / Interest El Queule                ',
#        'Interés x cbr Parronal / Interest Parronal                  ',
#        'Interés x cbr Villa Prat / Interest Villa Prat              ',
#        'Sueldo Robert Half / Payment Robert Half                    ',
#        'Asignación Teletrabajo / Telecommuting allocation           ',
#        'Costos Greenfield / Greenfield Cost                         ',
#        'Proyecto Andino Occidente / Andino Occidente Proyect        ',
#        'Proyecto Domeyko / Domeyko Proyect                          ',
#        'Proyecto Pelequen / Pelequen Proyect                        ',
#        'Proyecto Santa Lucía / Project Santa Lucía                  ',
#        'Impuesto Formulario 50 / Foreign Withholding Tax            ',
#        'Otros Impuestos / Other Taxes                               ',
#        'Intereses y multas / Interest and Penalty                   ',
#        'Traspaso de fondos Interco / Transfer of funds Interco      ',
#        'Depósitos a corto plazo / Short-term deposits               ',
#        'Cta Cte Emp Rel C-P Sx Metro / Related party current receiva',
#        'Ctas. Corr. Santa Lucía Solar / Current Receiv Santa Lucía S',
#        'Ctas. Corr. Corso Solar / Current Receiv Corso Solar        ',
#        'Ctas. Corr. Angamos Solar / Current Receiv Angamos Solar    ',
#        'Current Asset / Activo corriente CH2500 - SX Development    ',
#        'Current Asset / Activo corriente CH2400 - SX Operational    ',
#        'Ctas. Corr. SX Services / Current Receiv SX Services        ',
#        'Current Asset / Activo corriente CH2119 - Angamos           ',
#        'Current Asset / Activo corriente CH2121 - Santa Lucia       ',
#        'Ctas. Corr. Don Darío / Current Receiv Don Darío            ',
#        'Fondo Por Rendir Empleados / Employee Surrender Fund        ',
#        'Interés Diferido ROU / Deferred Interest ROU                ',
#        'Inv.EERR Metro Expansion / Investment Int. - Metro Expansion',
#        'Inv. SX Supplier / Investment Int. - SX Supplier            ',
#        'Inv. SX Development / Investment Int. - SX Development      ',
#        'Inv. SX Operational / Investment Int. - SX Operational      ',
#        'Inv. SX Services / Investment Int. - SX Services            ',
#        'Inv. Don Darío / Investment Int. - Don Darío                ',
#        'Anticipo de Clientes / Client Prepayment                    ',
#        'Ctas. Corr. Nueva Atacama / Current Liab - Nueva Atacama    ',
#        'Ctas. Corr. SX ET / Current Liab SX ET                      ',
#        'Ctas. Corr. SX UK / Current Liab  SX UK                     ',
#        'Inv. por pagar SPV P4 / Investments payable SPV P4          ',
#        'Inv. por pagar TRS / Investments payable TRS                ',
#        'Inv. por pagar NAS / Investments payable NAS                ',
#        'Inv. por pagar Andino / Investments payable Andino          ',
#        'Inv. por pagar SXET / Investments payable SXET              ',
#        'Inv. por pagar SXPPA / Investments payable SXPPA            ',
#        'Inv. por pagar SX Supplier / Investments payable SX Supplier',
#        'Inv. por pagar SX Development / Investments payable SX Devel',
#        'Inv. por pagar SX Operational / Investments payable SX Opera',
#        'Inv. por pagar SX Services / Investments payable SX Services',
#        'Inv. por pagar SX Metro / Investments payable SX Metro      ',
#        'Utilidades (Perdidas) Acumuladas / Retained Earnings (Loss) ',
#        'Assetmgmt fee income / honorarios AM CH2101 - Atacama       ',
#        'Assetmgmt fee income / honorarios AM CH2103 - Cox           ',
#        'Assetmgmt fee income / honorarios AM CH2104 - TRS           ',
#        'Assetmgmt fee income / honorarios AM CH1111 - Malinke       ',
#        'Assetmgmt fee income / honorarios AM CH2301 - Donihue       ',
#        'Assetmgmt fee income / honorarios AM CH2302 - Molina        ',
#        'Assetmgmt fee income / honorarios AM CH2303 - Potroso       ',
#        'Assetmgmt fee income / honorarios AM CH2304 - Marquesa      ',
#        'Assetmgmt fee income / honorarios AM CH2113 - Alto solar    ',
#        'Assetmgmt fee income / honorarios AM CH2115 - Parronal      ',
#        'Assetmgmt fee income / honorarios AM CH2114 - El Queule     ',
#        'Assetmgmt fee income / honorarios AM CH2116 - Villa Prat    ',
#        'Assetmgmt fee income / honorarios AM CH2117 - Taranto       ',
#        'Assetmgmt fee income / honorarios AM CH2112 - Crucero       ',
#        'Assetmgmt fee income / honorarios AM CH2102 - SPV P4        ',
#        'Interés x cbr SX Cox / Interest SX Cox                      ',
#        'Interés x cbr TRS / Interest TRS                            ',
#        'Interest inc / Ingreso por intereses CH2105 - NAS (USD)     ',
#        'Intereses SX Metro Expansion / Interest SX Metro Expansion  ',
#        'Interest inc / Ingreso por intereses CH2108 - SX ET (USD)   ',
#        'Interés x cbr SX PPA / Interest SX PPA                      ',
#        'Interest inc / Ingreso por intereses CH2118 - SX PPA (USD)  ',
#        'Interest inc / I.por intereses CH2400-SX Operational (USD)',
#        'Interest inc / I.por intereses CH2500-SX Development (USD)',
#        'costo del personal temporal / temporary staff cost          ',
#        'Sueldo de externos / external salary                        ',
#        'Marketing de potencia GFD / Power Marketing GFD             ',
#        'Otros gastos extraordinarios / Other extraordinary expenses ',
#        'Promoción & Publicidad / Advertising                        ',
#        'Otras Ganancias (Pérdidas) / Other Gains (Losses)           ',
#        'Honorario Consultores BD / Consultancy fees BD              ',
#        'El seguro de propiedad / Property insurance                 ',
#        'Gastos informáticos - software / IT expenses - software     ',
#        'Gastos de limpieza / Cleaning costs                         ',
#        'Refrigerios Oficina / Office Refreshments                   ',
#        'Gastos de Limpieza / Cleaning costs                         ',
#        'Asociaciones y suscripciones / Associations & Subscriptions ',
#        'Equipo de oficina / Office equipment                        ',
#        'Artículos para trabajadores / Articles for employees        ',
#        'Gastos Covid-19 / Covid-19 expenses                         '],
#       dtype=object)

# %%
tagua_tagua['NOMBRE CUENTA'].unique()
# Out:
# array(['Banco Santander CLP 7546  / Santander CLP Bank 7546         ',
#        'Banco Santander CLP 5151 / Santander CLP Bank 5151          ',
#        'Anticipo a Proveedores / Advances to suppliers              ',
#        'ActivoTerrenos arrendados (ROU) / Leased land asset (ROU)   ',
#        'Deprec Acum Terrenos arr (ROU) / Acc Dep Leased land (ROU)  ',
#        'Boleta en Garantía / Guaranteed deposits paid               ',
#        'Pasivo arrendamiento (ROU) / Lease liability (ROU)          ',
#        'Proveedores Nacionales / Trade Payables                     ',
#        'Proyecto TaguaTagua / TaguaTagua Proyect                    ',
#        'Combustibles / Fuel                                         ',
#        'Depreciación de arriendos de terreno (ROU) / Depreciation of',
#        'Alimentación / Meals (subsistence)                          ',
#        'Intereses de Pasivos por arrendamiento (ROU) / Lease liabili',
#        'No realizada gan/pérd - T/C / Unrealised FX profit or loss  ',
#        'Interés Diferido ROU / Deferred Interest ROU                ',
#        'Proyecto Tres Cruces / Tres Cruces Proyect                  '],
#       dtype=object)

# %%
joined_years
# Out:
#                                                                           CUENTA  \
# 11     1-1-1-01-10  Banco Santander CLP  / Santander CLP Bank
# 12     1-1-1-01-10  Banco Santander CLP  / Santander CLP Bank
# 13     1-1-1-01-10  Banco Santander CLP  / Santander CLP Bank
# 14     1-1-1-01-10  Banco Santander CLP  / Santander CLP Bank
# 15     1-1-1-01-10  Banco Santander CLP  / Santander CLP Bank
# ...                                                                          ...
# 21599  6-1-2-03-06  Ganancia/pérdida camb.Realizado UF/Realised FX profit/loss
# 21600  6-1-2-03-06  Ganancia/pérdida camb.Realizado UF/Realised FX profit/loss
# 21604  6-2-1-01-02  Impuesto Gastos Rechazados / Rejected Expenses
# 21608  6-2-1-01-03  Impuesto Diferido / Deferred Taxes
# 21612  6-2-1-01-04  Impuesto Diferido ROU / Deferred Taxes ROU
#
#            FECHA N° COMPROBANTE TIPO N° INTERNO TIPO DOC. NUMERO DOC     DEBE  \
# 11    2018-01-08       18010002    E   00000001        TR        801      0.0
# 12    2018-01-11       18010004    E   00000002        TR       1101      0.0
# 13    2018-01-12       18010006    E   00000003        TR       1201      0.0
# 14    2018-01-12       18010008    E   00000004        CH         48      0.0
# 15    2018-01-17       18010013    E   00000005        TR       1701      0.0
# ...          ...            ...  ...        ...       ...        ...      ...
# 21599 2022-11-24       22110175    T   00000007      None       None  6509.26
# 21600 2022-12-31       22120312    T   00000069      None       None      0.0
# 21604 2022-12-31       22120386    T   00000080      None       None   1304.7
# 21608 2022-12-31       22120385    T   00000079      None       None      0.0
# 21612 2022-12-31       22120385    T   00000079      None       None      0.0
#
#             HABER       SALDO  \
# 11        1782.06     82091.0
# 12        5409.35    76681.65
# 13        9328.46    67353.19
# 14         188.04    67165.15
# 15          38.17    67126.98
# ...           ...         ...
# 21599         0.0     6386.08
# 21600         0.0     6386.08
# 21604         0.0      1304.7
# 21608   309426.45  -309426.45
# 21612  1905932.84 -1905932.84
#
#                                                  DESCRIPCION   NRO CUENTA  \
# 11                    Pago anticipo notaria santelices - COX  1-1-1-01-10
# 12                                 Pago imposiciones Dic2017  1-1-1-01-10
# 13                         Pago Formulario 29 Diciembre 2017  1-1-1-01-10
# 14     Pago Derecho de obras complementarias - M. las condes  1-1-1-01-10
# 15                   Pago Patente Comercial 1° Semestre 2018  1-1-1-01-10
# ...                                                      ...          ...
# 21599                                      Cuenta de cuadre.  6-1-2-03-06
# 21600                                      Cuenta de cuadre.  6-1-2-03-06
# 21604    Provisión impuesto gastos rechazados AT2023 - Dic22  6-2-1-01-02
# 21608                         Impuesto Diferido 2022 - Dic22  6-2-1-01-03
# 21612                     Impuesto Diferido ROU 2022 - Dic22  6-2-1-01-04
#
#                                                       NOMBRE CUENTA  \
# 11     Banco Santander CLP  / Santander CLP Bank
# 12     Banco Santander CLP  / Santander CLP Bank
# 13     Banco Santander CLP  / Santander CLP Bank
# 14     Banco Santander CLP  / Santander CLP Bank
# 15     Banco Santander CLP  / Santander CLP Bank
# ...                                                             ...
# 21599  Ganancia/pérdida camb.Realizado UF/Realised FX profit/loss
# 21600  Ganancia/pérdida camb.Realizado UF/Realised FX profit/loss
# 21604  Impuesto Gastos Rechazados / Rejected Expenses
# 21608  Impuesto Diferido / Deferred Taxes
# 21612  Impuesto Diferido ROU / Deferred Taxes ROU
#
#             Account Name - English  \
# 11           Banco Santander CLP
# 12           Banco Santander CLP
# 13           Banco Santander CLP
# 14           Banco Santander CLP
# 15           Banco Santander CLP
# ...                            ...
# 21599                     Ganancia
# 21600                     Ganancia
# 21604  Impuesto Gastos Rechazados
# 21608           Impuesto Diferido
# 21612       Impuesto Diferido ROU
#
#                                     Account Name - Spanish
# 11                   Santander CLP Bank
# 12                   Santander CLP Bank
# 13                   Santander CLP Bank
# 14                   Santander CLP Bank
# 15                   Santander CLP Bank
# ...                                                    ...
# 21599  pérdida camb.Realizado UF/Realised FX profit/loss
# 21600  pérdida camb.Realizado UF/Realised FX profit/loss
# 21604                      Rejected Expenses
# 21608             Deferred Taxes
# 21612                 Deferred Taxes ROU
#
# [79630 rows x 15 columns]
