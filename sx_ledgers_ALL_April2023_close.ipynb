# %%
import pandas as pd
import xlwings as xw
import numpy as np
pd.set_option('display.max_columns', 1000, 'display.max_rows',1000, 'display.max_colwidth', None)

# z: 2018,a :2019, b:2020; c:2021; d:2022
# cumulative march :M

# sxc23M: sx chile March 23 (cum),
# pel21Y
# pel22Y
# pel23M
# dar22Y
# dar23M
# and20Y
# and21Y
# and22Y
# and23M


# locations

sxc23M_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\sxChile\20230331_SX Chile_General Ledger Mar23 (Acum).xlsx"
pel21Y_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\pelequen\20211231_Pelequen_General Ledger Dic21 (Acum).xlsx"
pel22Y_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\pelequen\20221231_Pelequén_General Ledger Dic22 (Acum)(17.Feb.2023).xlsx"
pel23M_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\pelequen\20230331_Pelequén_General Ledger Mar23 (Acum).xlsx"
dar22Y_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\donDario\20221231_Don Dario_General Ledger Dic22 (Acum) (17.Feb.2023).xlsx"
dar23M_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\donDario\20230331_Don Dario_General Ledger Mar23 (Acum).xlsx"
and20Y_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\andino\20201231_Parque Andino_Libro Mayor Dic20 (Acum).xlsx"
and21Y_location  = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\andino\20201231_Parque Andino_Libro Mayor Dic20 (Acum).xlsx"
and22Y_location  = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\andino\20221231_Parque Andino_General Ledger Dic22 (Acum) (14.04.2023).xlsx"
and23M_location = r"C:\Users\fernando.lamartine\Box\0 - Personal Working Folders (F Lamartine)\SX Chile General Ledgers\andino\20230331_Andino Occidente_General Ledger Mar23 (Acum).xlsx"


#filenames

sxc23M_filename = "20230331_SX Chile_General Ledger Mar23 (Acum).xlsx"
pel21Y_filename   = "20211231_Pelequen_General Ledger Dic21 (Acum).xlsx"
pel22Y_filename   = "20221231_Pelequén_General Ledger Dic22 (Acum)(17.Feb.2023).xlsx"
pel23M_filename  = "20230331_Pelequén_General Ledger Mar23 (Acum).xlsx"
dar22Y_filename   = "20221231_Don Dario_General Ledger Dic22 (Acum) (17.Feb.2023).xlsx"
dar23M_filename  = "20230331_Don Dario_General Ledger Mar23 (Acum).xlsx"
and20Y_filename   = "20201231_Parque Andino_Libro Mayor Dic20 (Acum).xlsx"
and21Y_filename   = "20211231_Parque Andino_General Ledger Dic21 (Acum).xlsx"
and22Y_filename   = "20221231_Parque Andino_General Ledger Dic22 (Acum) (14.04.2023).xlsx"
and23M_filename  = "20230331_Andino Occidente_General Ledger Mar23 (Acum).xlsx"

#dumpfile

dump_fileName = "sxLedgers_dumpFile.xlsx"
dump_rangeData = 'a1'
dump_rangeData_delete = 'a1:bb100000'
dump_sheet = 'Sheet1'
dump_sheet_2 = 'Sheet2'

#Range Data

sxc23M_rangeData = 'a1:o40000'
pel21Y_rangeData   = 'a1:o40000'
pel22Y_rangeData   = 'a1:o40000'
pel23M_rangeData  = 'a1:o40000'
dar22Y_rangeData   = 'a1:o40000'
dar23M_rangeData  = 'a1:o40000'
and20Y_rangeData   = 'a1:o40000'
and21Y_rangeData   = 'a1:o40000'
and22Y_rangeData   = 'a1:o40000'
and23M_rangeData  = 'a1:o40000'


sxc23M_sheet = 'CW20230410DFC0'
pel21Y_sheet   = 'CW20220124C534'
pel22Y_sheet   = 'CW202302173EE9'
pel23M_sheet  = 'CW2023041083E4'
dar22Y_sheet   = 'CW20230217B3F'
dar23M_sheet  = 'CW20230417D4F3'
and20Y_sheet   = 'CW202101156519'
and21Y_sheet   = 'CW20220121AB25'
and22Y_sheet   = 'CW20230412B923'
and23M_sheet  = 'CW202304101220'


sxc23M_book = xw.Book(sxc23M_filename)
pel21Y_book = xw.Book(pel21Y_filename)
pel22Y_book = xw.Book(pel22Y_filename)
pel23M_book = xw.Book(pel23M_filename)
dar22Y_book = xw.Book(dar22Y_filename)
dar23M_book = xw.Book(dar23M_filename)
and20Y_book = xw.Book(and20Y_filename)
and21Y_book = xw.Book(and21Y_filename)
and22Y_book = xw.Book(and22Y_filename)
and23M_book = xw.Book(and23M_filename)


"--------SXC23M--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
sxc23M_data = sxc23M_book.sheets(sxc23M_sheet).range(sxc23M_rangeData).value
df_sxc23M = pd.DataFrame(sxc23M_data)

#DROP UNNECESARY COLUMNS
df_sxc23M_2 = df_sxc23M.drop([5,6,7,10], axis=1)
df_sxc23M_3 = df_sxc23M_2[df_sxc23M_2[0].str.contains('SALDO ANTERIOR')==False]
df_sxc23M_4 = df_sxc23M_3.dropna(thresh=2)

# ACCOUNT NAMES
df_sxc23M_accounts = df_sxc23M_2[df_sxc23M_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_sxc23M_4.columns = df_sxc23M_4.iloc[0]
df_sxc23M_4 = df_sxc23M_4[1:]

#PARSE DATE
df_sxc23M_4['FECHA']=pd.to_datetime(df_sxc23M_4['FECHA'], dayfirst=True)

#COMPANY COLUMN
df_sxc23M_4['ENTITY']='sx_chile_holding'





"--------pel21Y--------------------------------------------------------------------------------------------------------"


#MAKE DATAFRAME FROM SPREADSHEET
pel21Y_data = pel21Y_book.sheets(pel21Y_sheet).range(pel21Y_rangeData).value
df_pel21Y = pd.DataFrame(pel21Y_data)

#DROP UNNECESARY COLUMNS
df_pel21Y_2 = df_pel21Y.drop([5,6,7,10], axis=1)
df_pel21Y_3 = df_pel21Y_2[df_pel21Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_pel21Y_4 = df_pel21Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_pel21Y_accounts = df_pel21Y_2[df_pel21Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_pel21Y_4.columns = df_pel21Y_4.iloc[0]
df_pel21Y_4 = df_pel21Y_4[1:]

#PARSE DATE
df_pel21Y_4['FECHA']=pd.to_datetime(df_pel21Y_4['FECHA'], dayfirst=True)

df_pel21Y_4['ENTITY']='pelequen'
"--------pel22Y--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
pel22Y_data = pel22Y_book.sheets(pel22Y_sheet).range(pel22Y_rangeData).value
df_pel22Y = pd.DataFrame(pel22Y_data)

#DROP UNNECESARY COLUMNS
df_pel22Y_2 = df_pel22Y.drop([5,6,7,10], axis=1)
df_pel22Y_3 = df_pel22Y_2[df_pel22Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_pel22Y_4 = df_pel22Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_pel22Y_accounts = df_pel22Y_2[df_pel22Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_pel22Y_4.columns = df_pel22Y_4.iloc[0]
df_pel22Y_4 = df_pel22Y_4[1:]

#PARSE DATE
df_pel22Y_4['FECHA']=pd.to_datetime(df_pel22Y_4['FECHA'], dayfirst=True)

df_pel22Y_4['ENTITY']='pelequen'
"--------pel23M--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
pel23M_data = pel23M_book.sheets(pel23M_sheet).range(pel23M_rangeData).value
df_pel23M = pd.DataFrame(pel23M_data)

#DROP UNNECESARY COLUMNS
df_pel23M_2 = df_pel23M.drop([5,6,7,10], axis=1)
df_pel23M_3 = df_pel23M_2[df_pel23M_2[0].str.contains('SALDO ANTERIOR')==False]
df_pel23M_4 = df_pel23M_3.dropna(thresh=2)

# ACCOUNT NAMES
df_pel23M_accounts = df_pel23M_2[df_pel23M_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_pel23M_4.columns = df_pel23M_4.iloc[0]
df_pel23M_4 = df_pel23M_4[1:]

#PARSE DATE
df_pel23M_4['FECHA']=pd.to_datetime(df_pel23M_4['FECHA'], dayfirst=True)

df_pel23M_4['ENTITY']='pelequen'


"--------dar22Y--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
dar22Y_data = dar22Y_book.sheets(dar22Y_sheet).range(dar22Y_rangeData).value
df_dar22Y = pd.DataFrame(dar22Y_data)

#DROP UNNECESARY COLUMNS
df_dar22Y_2 = df_dar22Y.drop([5,6,7,10], axis=1)
df_dar22Y_3 = df_dar22Y_2[df_dar22Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_dar22Y_4 = df_dar22Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_dar22Y_accounts = df_dar22Y_2[df_dar22Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_dar22Y_4.columns = df_dar22Y_4.iloc[0]
df_dar22Y_4 = df_dar22Y_4[1:]

#PARSE DATE
df_dar22Y_4['FECHA']=pd.to_datetime(df_dar22Y_4['FECHA'], dayfirst=True)

df_dar22Y_4['ENTITY']='don_dario'

"--------dar23M--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
dar23M_data = dar23M_book.sheets(dar23M_sheet).range(dar23M_rangeData).value
df_dar23M = pd.DataFrame(dar23M_data)

#DROP UNNECESARY COLUMNS
df_dar23M_2 = df_dar23M.drop([5,6,7,10], axis=1)
df_dar23M_3 = df_dar23M_2[df_dar23M_2[0].str.contains('SALDO ANTERIOR')==False]
df_dar23M_4 = df_dar23M_3.dropna(thresh=2)

# ACCOUNT NAMES
df_dar23M_accounts = df_dar23M_2[df_dar23M_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_dar23M_4.columns = df_dar23M_4.iloc[0]
df_dar23M_4 = df_dar23M_4[1:]

#PARSE DATE
df_dar23M_4['FECHA']=pd.to_datetime(df_dar23M_4['FECHA'], dayfirst=True)

df_dar23M_4['ENTITY']='don_dario'


"--------and20Y--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
and20Y_data = and20Y_book.sheets(and20Y_sheet).range(and20Y_rangeData).value
df_and20Y = pd.DataFrame(and20Y_data)

#DROP UNNECESARY COLUMNS
df_and20Y_2 = df_and20Y.drop([5,6,7,10], axis=1)
df_and20Y_3 = df_and20Y_2[df_and20Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_and20Y_4 = df_and20Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_and20Y_accounts = df_and20Y_2[df_and20Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_and20Y_4.columns = df_and20Y_4.iloc[0]
df_and20Y_4 = df_and20Y_4[1:]

#PARSE DATE
df_and20Y_4['FECHA']=pd.to_datetime(df_and20Y_4['FECHA'], dayfirst=True)

df_and20Y_4['ENTITY']='andino'
"--------and21Y--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
and21Y_data = and21Y_book.sheets(and21Y_sheet).range(and21Y_rangeData).value
df_and21Y = pd.DataFrame(and21Y_data)

#DROP UNNECESARY COLUMNS
df_and21Y_2 = df_and21Y.drop([5,6,7,10], axis=1)
df_and21Y_3 = df_and21Y_2[df_and21Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_and21Y_4 = df_and21Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_and21Y_accounts = df_and21Y_2[df_and21Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_and21Y_4.columns = df_and21Y_4.iloc[0]
df_and21Y_4 = df_and21Y_4[1:]

#PARSE DATE
df_and21Y_4['FECHA']=pd.to_datetime(df_and21Y_4['FECHA'], dayfirst=True)

df_and21Y_4['ENTITY']='andino'
"--------and22Y--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
and22Y_data = and22Y_book.sheets(and22Y_sheet).range(and22Y_rangeData).value
df_and22Y = pd.DataFrame(and22Y_data)

#DROP UNNECESARY COLUMNS
df_and22Y_2 = df_and22Y.drop([5,6,7,10], axis=1)
df_and22Y_3 = df_and22Y_2[df_and22Y_2[0].str.contains('SALDO ANTERIOR')==False]
df_and22Y_4 = df_and22Y_3.dropna(thresh=2)

# ACCOUNT NAMES
df_and22Y_accounts = df_and22Y_2[df_and22Y_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_and22Y_4.columns = df_and22Y_4.iloc[0]
df_and22Y_4 = df_and22Y_4[1:]

#PARSE DATE
df_and22Y_4['FECHA']=pd.to_datetime(df_and22Y_4['FECHA'], dayfirst=True)

df_and22Y_4['ENTITY']='andino'
"--------and23M--------------------------------------------------------------------------------------------------------"

#MAKE DATAFRAME FROM SPREADSHEET
and23M_data = and23M_book.sheets(and23M_sheet).range(and23M_rangeData).value
df_and23M = pd.DataFrame(and23M_data)

#DROP UNNECESARY COLUMNS
df_and23M_2 = df_and23M.drop([5,6,7,10], axis=1)
df_and23M_3 = df_and23M_2[df_and23M_2[0].str.contains('SALDO ANTERIOR')==False]
df_and23M_4 = df_and23M_3.dropna(thresh=2)

# ACCOUNT NAMES
df_and23M_accounts = df_and23M_2[df_and23M_2[0].str.contains('SALDO ANTERIOR')==True]

#MAKING ROW ONE THE HEADER
df_and23M_4.columns = df_and23M_4.iloc[0]
df_and23M_4 = df_and23M_4[1:]

#PARSE DATE
df_and23M_4['FECHA']=pd.to_datetime(df_and23M_4['FECHA'], dayfirst=True)

df_and23M_4['ENTITY']='andino'



# sxc23M: sx chile March 23 (cum),
# pel21Y
# pel22Y
# pel23M
# dar22Y
# dar23M
# and20Y
# and21Y
# and22Y
# and23M



joined_years = pd.concat([df_sxc23M_4,df_pel21Y_4,df_pel22Y_4,df_pel23M_4,df_dar22Y_4,df_dar22Y_4,df_dar23M_4,
                          df_and20Y_4,df_and21Y_4,df_and22Y_4,df_and23M_4,])

acct_uniques = joined_years['CUENTA'].unique()

ACCOUNT = joined_years['CUENTA'].str.split(n=1, expand=True)
joined_years['NRO CUENTA'] = ACCOUNT[0]
joined_years['NOMBRE CUENTA'] = ACCOUNT[1]

#SECOND SPLIT

NOMBRE_CUENTA = joined_years['NOMBRE CUENTA'].str.split("/", n=1, expand=True)
joined_years['Account Name - English'] =NOMBRE_CUENTA[0]
joined_years['Account Name - Spanish'] = NOMBRE_CUENTA[1]



xw.Book(dump_fileName).sheets(dump_sheet).range(dump_rangeData_delete).value = ""
xw.Book(dump_fileName).sheets(dump_sheet).range(dump_rangeData).value = joined_years
# xw.Book(dump_fileName).sheets(dump_sheet_2).range(dump_rangeData_delete).value = ""
# xw.Book(dump_fileName).sheets(dump_sheet_2).range("a1:a1000").value = acct_uniques


joined_years
# Out:
# 8                                                                      CUENTA  \
# 12  1-1-1-01-10  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 13  1-1-1-01-10  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 14  1-1-1-01-10  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 15  1-1-1-01-10  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 16  1-1-1-01-10  Banco Santander CLP 7546  / Santander CLP Bank 7546
# ..                                                                        ...
# 88  6-1-1-27-21  Patentes Permisos / Licenses & Permits
# 89  6-1-1-27-21  Patentes Permisos / Licenses & Permits
# 93  6-1-2-03-04  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
# 94  6-1-2-03-04  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
# 95  6-1-2-03-04  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
#
# 8       FECHA N° COMPROBANTE TIPO N° INTERNO TIPO DOC. NUMERO DOC    DEBE  \
# 12 2023-01-04       23010115    T   00000004        TR        401     0.0
# 13 2023-01-04       23010115    T   00000004        TR        401     0.0
# 14 2023-01-06       23010007    E   00000000        TR        501     0.0
# 15 2023-01-06       23010007    E   00000000        TR        501     0.0
# 16 2023-01-06       23010116    E   00000005        TR        601     0.0
# ..        ...            ...  ...        ...       ...        ...     ...
# 88 2023-03-30       23030005    T   00000004      None       None  151.15
# 89 2023-03-30       23030005    T   00000004      None       None  151.15
# 93 2023-01-31       23010002    T   00000002      None       None     0.0
# 94 2023-02-28       23020004    T   00000002      None       None    0.18
# 95 2023-03-31       23030004    T   00000003      None       None     0.0
#
# 8     HABER     SALDO                                          DESCRIPCION  \
# 12   677.25  94517.48    Pago FA 10516943 Dimerc SA - Insumo oficina Dic22
# 13     31.7  94485.78               Pago RG20221124 E.Barravecchia - Nov22
# 14    263.2  94222.58  Pago Publicación DO y Decreto Concesión Tres Cruces
# 15   9080.0  85142.58          Pago FE 4474 DET NORSKE VERITAS CHILE LTDA.
# 16  7951.78   77190.8                   Pago Finiquito Trabajadores - En23
# ..      ...       ...                                                  ...
# 88      0.0   1275.43                 Patente Minera Andino OI III - Mar23
# 89      0.0   1426.58                  Patente Minera Andino OI IV - Mar23
# 93     0.13     -0.13                            Ajuste TC IVA C/F - Ene23
# 94      0.0      0.05                            Ajuste TC IVA C/F - Feb23
# 95     0.26     -0.21                            Ajuste TC IVA C/F - Mar23
#
# 8             ENTITY   NRO CUENTA  \
# 12  sx_chile_holding  1-1-1-01-10
# 13  sx_chile_holding  1-1-1-01-10
# 14  sx_chile_holding  1-1-1-01-10
# 15  sx_chile_holding  1-1-1-01-10
# 16  sx_chile_holding  1-1-1-01-10
# ..               ...          ...
# 88            andino  6-1-1-27-21
# 89            andino  6-1-1-27-21
# 93            andino  6-1-2-03-04
# 94            andino  6-1-2-03-04
# 95            andino  6-1-2-03-04
#
# 8                                                  NOMBRE CUENTA  \
# 12  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 13  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 14  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 15  Banco Santander CLP 7546  / Santander CLP Bank 7546
# 16  Banco Santander CLP 7546  / Santander CLP Bank 7546
# ..                                                           ...
# 88  Patentes Permisos / Licenses & Permits
# 89  Patentes Permisos / Licenses & Permits
# 93  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
# 94  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
# 95  Dif TC No realizada (gan-pérd)/ Unrealised FX profit or loss
#
# 8           Account Name - English                     Account Name - Spanish
# 12      Banco Santander CLP 7546             Santander CLP Bank 7546
# 13      Banco Santander CLP 7546             Santander CLP Bank 7546
# 14      Banco Santander CLP 7546             Santander CLP Bank 7546
# 15      Banco Santander CLP 7546             Santander CLP Bank 7546
# 16      Banco Santander CLP 7546             Santander CLP Bank 7546
# ..                             ...                                        ...
# 88              Patentes Permisos    Licenses & Permits
# 89              Patentes Permisos    Licenses & Permits
# 93  Dif TC No realizada (gan-pérd)               Unrealised FX profit or loss
# 94  Dif TC No realizada (gan-pérd)               Unrealised FX profit or loss
# 95  Dif TC No realizada (gan-pérd)               Unrealised FX profit or loss
#
# [5793 rows x 16 columns]
